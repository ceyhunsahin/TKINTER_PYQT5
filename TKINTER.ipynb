# %%
 import tkinter as tk

# %%
from tkinter import ttk

# %%
window = tk.Tk() # tk kutuphanesinden Tk() classini cagirdik ve 1 obje yarattik

# %%
window.geometry("500x450") # size ini ayarladik, x ekseninde 500 piksel, y ekseninde 450 piksel
window.title("Welcome to first application")
# Out:
# ''

# %%
def buttonFunction():
    print("Push Button")

# %%
button = tk.Button(window, text = "First Button", activebackground = 'red', bg = "black", fg = 'green', activeforeground = "black", height = 15, width = 50, command = buttonFunction) # benim butonumun uzerinde olacak bu button

# %%
button.pack() # bu widget i window a eklemek icin sart

# %%
window.mainloop()
# Out:
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button
# Push Button

# %%
 import tkinter as tk
 from tkinter import messagebox
 window = tk.Tk()
 window.geometry("500x450") # size ini ayarladik, x ekseninde 500 piksel, y ekseninde 450 piksel
 window.title("Welcome to first application")
 def buttonFunction():
    print("Push Button")
    # Label
    label.config(text = "hello world",
    fg = "black",
    bg = "red",
    font = "Times 25")

button = tk.Button(window, text = "First Button", activebackground = 'red', bg = "black", fg = 'green', activeforeground = "black", height = 15, width = 50, command = buttonFunction) 
button.pack()

label = tk.Label(window, text = "Hi World", font = "Times 16", fg = "white", bg = "black",wraplength=150)

label.pack(side = tk.RIGHT, padx = 25)

window.mainloop()
# Out:
# Push Button
# Push Button

# %%
 import tkinter as tk
 from tkinter import ttk
 window = tk.Tk()
 window.geometry("500x450") # size ini ayarladik, x ekseninde 500 piksel, y ekseninde 450 piksel
 window.title("Welcome to first application")
 def buttonFunction():
    print("Push Button")
    # Label
    label.config(text = "hello world",
    fg = "black",
    bg = "red",
    font = "Times 25")
    value = entry.get()
    print(value)
    label.configure(text = value)
    entry.configure(state= "disabled")

button = tk.Button(window, text = "First Button", activebackground = 'red', bg = "black", fg = 'green', activeforeground = "black", height = 15, width = 50, command = buttonFunction) 
button.pack()

label = tk.Label(window, text = "Hi World", font = "Times 16", fg = "white", bg = "black",wraplength=150)

label.pack(side = tk.RIGHT, padx = 25)

entry = tk.Entry(window, width = 50)
entry.insert(string = "write something only one time", index = 0)# verilen indexe gore 1 kere yazi ciksin istiyorum
entry.pack(side = tk.LEFT, padx = 25)

window.mainloop()
# Out:
# Push Button
# write something only one time

# %%
 import tkinter as tk
 from tkinter import ttk
 from tkinter import messagebox
 window = tk.Tk()
 window.geometry("500x450") # size ini ayarladik, x ekseninde 500 piksel, y ekseninde 450 piksel
 window.title("Welcome to first application")
 def buttonFunction():
    print("Push Button")
    # Label
    label.config(text = "hello world",
    fg = "black",
    bg = "red",
    font = "Times 25")
    value = entry.get()
    print(value)
    label.configure(text = value)
    entry.configure(state= "disabled")

    #message
    #message_box = messagebox.showinfo(title = "info", message= "information")
    #message_box = messagebox.askretrycancel(title = "info", message= "information")
    #message_box = messagebox.askquestion(title = "info", message= "information")
    #message_box = messagebox.askyesnocancel(title = "info", message= "information")
    #message_box = messagebox.showerror(title = "info", message= "information")
    message_box = messagebox.showinfo(title = "info", message= "kardesimmm nerdesin sen")
    print(message_box)

button = tk.Button(window, text = "First Button", activebackground = 'red', bg = "black", fg = 'green', activeforeground = "black", height = 15, width = 50, command = buttonFunction) 
button.pack()

label = tk.Label(window, text = "Hi World", font = "Times 16", fg = "white", bg = "black",wraplength=150)

label.pack(side = tk.RIGHT, padx = 25)

entry = tk.Entry(window, width = 50)
entry.insert(string = "write something only one time", index = 0)# verilen indexe gore 1 kere yazi ciksin istiyorum
entry.pack(side = tk.LEFT, padx = 25)

window.mainloop()
# Out:
# Push Button
# write something only one time
# ok

# %%
 # GEOMETRY MANAGER
 import tkinter as tk
 from tkinter import ttk
 from tkinter import messagebox
 window = tk.Tk()
 window.geometry("500x450") # size ini ayarladik, x ekseninde 500 piksel, y ekseninde 450 piksel
 window.title("Welcome to first application")
 def buttonFunction():
    print("Push Button")
    # Label
    label.config(text = "hello world",
    fg = "black",
    bg = "red",
    font = "Times 25")
    value = entry.get()
    print(value)
    label.configure(text = value)
    entry.configure(state= "disabled")

    #message
    #message_box = messagebox.showinfo(title = "info", message= "information")
    #message_box = messagebox.askretrycancel(title = "info", message= "information")
    #message_box = messagebox.askquestion(title = "info", message= "information")
    #message_box = messagebox.askyesnocancel(title = "info", message= "information")
    #message_box = messagebox.showerror(title = "info", message= "information")
    message_box = messagebox.showinfo(title = "info", message= "kardesimmm nerdesin sen")
    print(message_box)

button = tk.Button(window, text = "First Button", activebackground = 'red', bg = "black", fg = 'green', activeforeground = "black", height = 15, width = 50, command = buttonFunction) 
button.pack()

label = tk.Label(window, text = "Hi World", font = "Times 16", fg = "white", bg = "black",wraplength=150)

label.pack(side = tk.RIGHT, padx = 25)

entry = tk.Entry(window, width = 50)
entry.insert(string = "write something only one time", index = 0)# verilen indexe gore 1 kere yazi ciksin istiyorum
entry.pack(side = tk.LEFT, padx = 25)

window.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

window = tk.Tk()
window.title("Geometry Manager")
window.mainloop()

# %%
# PACK
import tkinter as tk
from tkinter import ttk

window = tk.Tk()
window.title("Geometry Manager")


red = tk.Button(window, text = "Red", fg = "red")
green = tk.Button(window, text = "Green", activebackground="gray", activeforeground="purple", background="purple", fg="green")
blue = tk.Button(window, text = "Blue", fg = "blue")
black = tk.Button(window, text = "Black", fg = "black")
brown = tk.Button(window, text = "Brown", fg = "brown")
cyan= tk.Button(window, text = "Cyan", fg = "cyan")
blue.pack(side = tk.LEFT)
red.pack(side = tk.LEFT)
green.pack(side = tk.LEFT)
black.pack(side = tk.BOTTOM)
brown.pack(side = tk.BOTTOM)
cyan.pack(side = tk.TOP, fill = tk.BOTH, expand = True)

window.mainloop()

# %%
# GRID METHOD
import tkinter as tk
from tkinter import ttk

window = tk.Tk()
window.title("Geometry Manager")

for r in range(5):
    for c in range(5):
        label = tk.Label(window, text='R%s/C%s'%(r,c),borderwidth = 10)
        label.grid(row = r, column = c, padx = 3, pady = 3)

window.mainloop()

# %%
# PLACE METHOD

import tkinter as tk
from tkinter import ttk

window = tk.Tk()
window.title("Geometry Manager")

label1 = tk.Label(window, text = "place1")
label1.place(x=15, y = 15)

label2 = tk.Label(window, text = "place2")
label2.place(x=35, y = 35)

label3 = tk.Label(window, text = "place3")
label3.place(x=55, y = 55)

label4 = tk.Label(window, text = "place4")
label4.place(relx=0.9, rely = 0.9)

label5= tk.Label(window, text = "place5")
label5.place(relx=0, rely = 0)

window.mainloop()

# %%
# RADIO BUTTON

import tkinter as tk
from tkinter import ttk

window = tk.Tk()
window.geometry("500x450")

def buttonFunc():
    print("here")
    #radio button
    m = method.get()
    if m == "1":
        print("method1")
    elif m == "2":
        print("method2")
    else:
        print("method1 & method2")




button = tk.Button(window, text = "Button", activebackground="red", bg="black", fg="red", activeforeground="black",
height = 15, width = 50, command = buttonFunc)


button.grid(row = 0, column = 0, pady=15)

#radio button

method = tk.StringVar()
tk.Radiobutton(window, text = "method1: ", value = "1", activebackground="red", bg="green",
height = 5, width = 5,  borderwidth=15, variable = method).grid(row = 1, column = 0)

tk.Radiobutton(window, text = "method2: ", value = "2", activebackground="red", bg="green",
height = 5, width = 5,  borderwidth=15, variable = method).grid(row = 1, column = 1, pady = 15)



window.mainloop()
# Out:
# here
# method1 & method2
# here
# method1 & method2
# here
# method1
# here
# method2
# here
# method1

# %%
# COMBO BOX

import tkinter as tk
from tkinter import ttk

window = tk.Tk()
window.geometry("500x450")

def buttonFunc():
    print("here")
    #radio button
    m = method.get()
    if m == "1":
        print("method1")
    elif m == "2":
        print("method2")
    else:
        print("method1 & method2")

    #comboBox

    print(problem.get())




button = tk.Button(window, text = "Button", activebackground="red", bg="black", fg="red", activeforeground="black",
height = 15, width = 50, command = buttonFunc)


button.grid(row = 0, column = 0, pady=15)

#radio button

method = tk.StringVar()
tk.Radiobutton(window, text = "method1: ", value = "1", activebackground="red", bg="green",
height = 5, width = 5,  borderwidth=15, variable = method).grid(row = 1, column = 0)

tk.Radiobutton(window, text = "method2: ", value = "2", activebackground="red", bg="green",
height = 5, width = 5,  borderwidth=15, variable = method).grid(row = 1, column = 1, pady = 15)

problem = tk.StringVar()
comboBox = ttk.Combobox(window, textvariable= problem, values=("1","2","3"), state="readonly")
comboBox.grid(row = 2, column=0, pady=15)



window.mainloop()
# Out:
# here
# method1 & method2
# 2

# %%
# Check Button

import tkinter as tk
from tkinter import ttk

window = tk.Tk()
window.geometry("500x450")

def buttonFunc():
    print("here")
    #radio button
    m = method.get()
    if m == "1":
        print("method1")
    elif m == "2":
        print("method2")
    else:
        print("method1 & method2")

    #comboBox

    print(problem.get())

    #checkButton

    value = save_var.get()
    if value ==1:
        print("Save__")
    else:
        print("not save")



button = tk.Button(window, text = "Button", activebackground="red", bg="black", fg="red", activeforeground="black",
height = 15, width = 50, command = buttonFunc)


button.grid(row = 0, column = 0, pady=15)

#radio button

method = tk.StringVar()
tk.Radiobutton(window, text = "method1: ", value = "1", activebackground="red", bg="green",
height = 5, width = 5,  borderwidth=15, variable = method).grid(row = 1, column = 0)

tk.Radiobutton(window, text = "method2: ", value = "2", activebackground="red", bg="green",
height = 5, width = 5,  borderwidth=15, variable = method).grid(row = 1, column = 1, pady = 15)

problem = tk.StringVar()
comboBox = ttk.Combobox(window, textvariable= problem, values=("1","2","3"), state="readonly")
comboBox.grid(row = 2, column=0, pady=15)

def checkButtonFunc():
    print("save")

save_var=tk.IntVar()
save_var.set(0)  #index o0 a set ettik
c_button = tk.Checkbutton(window, text = 'Save', variable = save_var, font = "Times 25", activebackground="green",
activeforeground="white",
bg = "yellow", command=checkButtonFunc)

c_button.grid(row = 2, column = 1, pady = 15)



window.mainloop()
# Out:
# here
# method1 & method2
#
# not save
# save
# save
# save
# here
# method1 & method2
#
# Save__

# %%
# Frames bir arayuz uzerinde widgetlari organize etme, kumeleme icin kullanilir
import tkinter as tk
from tkinter import ttk

window = tk.Tk() # high Level Window

frame_left = tk.Frame(window, width = 540, height=640, bg = "red")
frame_left.grid(row = 0, column = 0, padx=10, pady=10)

frame_right = tk.Frame(window, width = 540, height=640, bg="green")
frame_right.grid(row = 0, column = 1, padx=10, pady=10)


frame1 = tk.LabelFrame(frame_left, text="frame1",width = 540, height=500, bg = "yellow")
frame1.grid(row = 0, column = 0, padx=10, pady=10)

frame2 = tk.LabelFrame(frame_left, text="frame2", width = 540, height=140, bg = "yellow")
frame2.grid(row = 1, column = 0, padx=10, pady=10)

#frame3 = tk.LabelFrame(frame2, text="frame3",width = 300, height=140, bg = "cyan")
#frame3.grid(row = 1, column = 0, padx=10, pady=10)

#frame4 = tk.LabelFrame(frame2, text="frame4", width = 240, height=140, bg = "cyan")
#frame4.grid(row = 1, column = 1, padx=10, pady=10)

label1 = tk.Label(frame2, text = "Label in Frame2")
label1.grid(row = 1, column=0, padx=10, pady=10 )



window.mainloop()

# %%
# Paned Window, framelere benzer frameleri, widgetleri ve panelleri organize etmeye yarar

import tkinter as tk
from tkinter import ttk

window = tk.Tk() # high Level Window

#frame_left = tk.Frame(window, width = 540, height=640, bg = "red")
#frame_left.grid(row = 0, column = 0, padx=10, pady=10)

#frame_right = tk.Frame(window, width = 540, height=640, bg="green")
##frame_right.grid(row = 0, column = 1, padx=10, pady=10)


#frame1 = tk.LabelFrame(frame_left, text="frame1",width = 540, height=500, bg = "yellow")
#frame1.grid(row = 0, column = 0, padx=10, pady=10)

#frame2 = tk.LabelFrame(frame_left, text="frame2", width = 540, height=140, bg = "yellow")
#frame2.grid(row = 1, column = 0, padx=10, pady=10)

#frame3 = tk.LabelFrame(frame2, text="frame3",width = 300, height=140, bg = "cyan")
#frame3.grid(row = 1, column = 0, padx=10, pady=10)

#frame4 = tk.LabelFrame(frame2, text="frame4", width = 240, height=140, bg = "cyan")
#frame4.grid(row = 1, column = 1, padx=10, pady=10)

#label1 = tk.Label(frame2, text = "Label in Frame2")
#label1.grid(row = 1, column=0, padx=10, pady=10 )

# paned window

pw = ttk.PanedWindow(window, orient=tk.HORIZONTAL)
pw.pack(fill= tk.BOTH, expand = True)

m2 = ttk.PanedWindow(pw, orient=tk.VERTICAL) # 2.paned window

frame2 = ttk.Frame(pw, width=720, height=400, relief=tk.RIDGE)
frame3 = ttk.Frame(pw, width=720, height=240, relief=tk.RAISED)
m2.add(frame2)
m2.add(frame3)

frame1 = ttk.Frame(pw, width=360, height=640, relief=tk.GROOVE)
pw.add(m2)
pw.add(frame1)


window.mainloop()

# %%
# MENU

import tkinter as tk
from tkinter import ttk

window = tk.Tk() # high Level Window
window.geometry("800x600")


def FileFunction():
    print("here")



menubar = tk.Menu(window)
window.config(menu= menubar)

file = tk.Menu(menubar)
edit = tk.Menu(menubar)

menubar.add_cascade(label="file", menu = file)
menubar.add_cascade(label= "edit", menu = edit)

file.add_command(label = "new file", command = FileFunction)
edit.add_command(label = "undo", command = FileFunction)


window.mainloop()
# Out:
# here

# %%
 ##TABS
    
import tkinter as tk
from tkinter import ttk

window = tk.Tk() # high Level Window
window.geometry("800x600")


def FileFunction():
    print("here")



menubar = tk.Menu(window)
window.config(menu= menubar)

file = tk.Menu(menubar)
edit = tk.Menu(menubar)

menubar.add_cascade(label="file", menu = file)
menubar.add_cascade(label= "edit", menu = edit)

file.add_command(label = "new file", command = FileFunction)
edit.add_command(label = "undo", command = FileFunction)

#tabs


tabs = ttk.Notebook(window, width = 540, height = 300)
tabs.place(x = 25, y = 25)

tab1 = ttk.Frame(tabs, width = 50, height = 50)
tab2 = ttk.Frame(tabs, width = 50, height = 50)
tab3 = ttk.Frame(tabs, width = 50, height = 50)

tk.Label(tab1, text = "tab1").pack()
tk.Label(tab2, text = "tab2").pack()
tk.Label(tab3, text = "tab3").pack()

tabs.add(tab1, text = "treeview")
tabs.add(tab2, text = "listbox")
tabs.add(tab3, text = "text editor")





window.mainloop()

# %%
## TREEVIEW

    
import tkinter as tk
from tkinter import ttk

window = tk.Tk() # high Level Window
window.geometry("800x600")


def FileFunction():
    print("here")



menubar = tk.Menu(window)
window.config(menu= menubar)

file = tk.Menu(menubar)
edit = tk.Menu(menubar)

menubar.add_cascade(label="file", menu = file)
menubar.add_cascade(label= "edit", menu = edit)

file.add_command(label = "new file", command = FileFunction)
edit.add_command(label = "undo", command = FileFunction)

#tabs


tabs = ttk.Notebook(window, width = 540, height = 300)
tabs.place(x = 25, y = 25)

tab1 = ttk.Frame(tabs, width = 50, height = 50)
tab2 = ttk.Frame(tabs, width = 50, height = 50)
tab3 = ttk.Frame(tabs, width = 50, height = 50)

tk.Label(tab1, text = "tab1").pack()
tk.Label(tab2, text = "tab2").pack()
tk.Label(tab3, text = "tab3").pack()

tabs.add(tab1, text = "treeview")
tabs.add(tab2, text = "listbox")
tabs.add(tab3, text = "text editor")

treeview = ttk.Treeview(tab1)
treeview.place(x = 5, y = 5)

treeview.insert("","0" ,"item1", text="Spain")
treeview.insert("item1", "1", "item2", text="Madrid")
treeview.insert("", "2", "item3", text="France")
treeview.insert("item3", "4", "item4", text="Paris")


def callback(event) : 
    item= treeview.identify("item", event.x, event.y)
    print(item)

treeview.bind("<Double-1>", callback)

window.mainloop()
# Out:
# item2
# item3
# item4
# item1
# item3
#
# item3
# item4
#
#
# item1
# item2

# %%
### LISTBOX
import tkinter as tk
from tkinter import ttk

window = tk.Tk() # high Level Window
window.geometry("800x600")


def FileFunction():
    print("here")



menubar = tk.Menu(window)
window.config(menu= menubar)

file = tk.Menu(menubar)
edit = tk.Menu(menubar)

menubar.add_cascade(label="file", menu = file)
menubar.add_cascade(label= "edit", menu = edit)

file.add_command(label = "new file", command = FileFunction)
edit.add_command(label = "undo", command = FileFunction)

#tabs


tabs = ttk.Notebook(window, width = 540, height = 300)
tabs.place(x = 25, y = 25)

tab1 = ttk.Frame(tabs, width = 50, height = 50)
tab2 = ttk.Frame(tabs, width = 50, height = 50)
tab3 = ttk.Frame(tabs, width = 50, height = 50)

tk.Label(tab1, text = "tab1").pack()
tk.Label(tab2, text = "tab2").pack()
tk.Label(tab3, text = "tab3").pack()

tabs.add(tab1, text = "treeview")
tabs.add(tab2, text = "listbox")
tabs.add(tab3, text = "text editor")

treeview = ttk.Treeview(tab1)
treeview.place(x = 5, y = 5)

treeview.insert("","0" ,"item1", text="Spain")
treeview.insert("item1", "1", "item2", text="Madrid")
treeview.insert("", "2", "item3", text="France")
treeview.insert("item3", "4", "item4", text="Paris")


def callback(event) : 
    item= treeview.identify("item", event.x, event.y)
    print(item)

treeview.bind("<Double-1>", callback)

# LISTBOX
#farkli farkli itemlari depolamak icin kullandigimiz yapilardir

listBox = tk.Listbox(tab2, selectmode=tk.MULTIPLE)
listBox.insert(0,"Spain")
listBox.insert(1,"France")
listBox.insert(2,"China")

listBox.place(x=5, y = 5)
def getItem():
    index_list = listBox.curselection()
    print(index_list)
    for each in index_list:
        print(listBox.get(each))

button = tk.Button(tab2, text="button", command = getItem)
button.place(x = 220, y = 5)



window.mainloop()
# Out:
# (0,)
# Spain
# (0, 1)
# Spain
# France
# (0, 2)
# Spain
# China
# (1, 2)
# France
# China

# %%
## TEXT EDITOR
import tkinter as tk
from tkinter import ttk

window = tk.Tk() # high Level Window
window.geometry("800x600")


def FileFunction():
    print("here")



menubar = tk.Menu(window)
window.config(menu= menubar)

file = tk.Menu(menubar)
edit = tk.Menu(menubar)

menubar.add_cascade(label="file", menu = file)
menubar.add_cascade(label= "edit", menu = edit)

file.add_command(label = "new file", command = FileFunction)
edit.add_command(label = "undo", command = FileFunction)

#tabs


tabs = ttk.Notebook(window, width = 540, height = 300)
tabs.place(x = 25, y = 25)

tab1 = ttk.Frame(tabs, width = 50, height = 50)
tab2 = ttk.Frame(tabs, width = 50, height = 50)
tab3 = ttk.Frame(tabs, width = 50, height = 50)

tk.Label(tab1, text = "tab1").pack()
tk.Label(tab2, text = "tab2").pack()
#tk.Label(tab3, text = "tab3").pack()
#tk.Label(tab3, text = "tab3").grid()  asagida kullaniyoruz

tabs.add(tab1, text = "treeview")
tabs.add(tab2, text = "listbox")
tabs.add(tab3, text = "text editor")

treeview = ttk.Treeview(tab1)
treeview.place(x = 5, y = 5)

treeview.insert("","0" ,"item1", text="Spain")
treeview.insert("item1", "1", "item2", text="Madrid")
treeview.insert("", "2", "item3", text="France")
treeview.insert("item3", "4", "item4", text="Paris")


def callback(event) : 
    item= treeview.identify("item", event.x, event.y)
    print(item)

treeview.bind("<Double-1>", callback)

# LISTBOX
#farkli farkli itemlari depolamak icin kullandigimiz yapilardir

listBox = tk.Listbox(tab2, selectmode=tk.MULTIPLE)
listBox.insert(0,"Spain")
listBox.insert(1,"France")
listBox.insert(2,"China")

listBox.place(x=5, y = 5)
def getItem():
    index_list = listBox.curselection()
    print(index_list)
    for each in index_list:
        print(listBox.get(each))

button = tk.Button(tab2, text="button", command = getItem)
button.place(x = 220, y = 5)


# Text EDITOR

texteditor = tk.Text(tab3, width = 25, height = 25, wrap = tk.WORD)
texteditor.grid(row = 0, column = 0, padx=10,pady=10)


def textFunction():
    print(texteditor.get(1.0,tk.END))



button = tk.Button(tab3, text="save", command = textFunction)
button.grid(row = 0, column = 1, padx=10,pady=10)




window.mainloop()
# Out:
# azdfaZDFAz
#
# azdfaZDFAzaDZAadz

# %%
##Scroll bar
import tkinter as tk
from tkinter import ttk

window = tk.Tk() # high Level Window
window.geometry("800x600")


def FileFunction():
    print("here")



menubar = tk.Menu(window)
window.config(menu= menubar)

file = tk.Menu(menubar)
edit = tk.Menu(menubar)

menubar.add_cascade(label="file", menu = file)
menubar.add_cascade(label= "edit", menu = edit)

file.add_command(label = "new file", command = FileFunction)
edit.add_command(label = "undo", command = FileFunction)

#tabs


tabs = ttk.Notebook(window, width = 540, height = 300)
tabs.place(x = 25, y = 25)

tab1 = ttk.Frame(tabs, width = 50, height = 50)
tab2 = ttk.Frame(tabs, width = 50, height = 50)
tab3 = ttk.Frame(tabs, width = 50, height = 50)

tk.Label(tab1, text = "tab1").pack()
tk.Label(tab2, text = "tab2").pack()
#tk.Label(tab3, text = "tab3").pack()
#tk.Label(tab3, text = "tab3").grid()  asagida kullaniyoruz

tabs.add(tab1, text = "treeview")
tabs.add(tab2, text = "listbox")
tabs.add(tab3, text = "text editor")

treeview = ttk.Treeview(tab1)
treeview.place(x = 5, y = 5)

treeview.insert("","0" ,"item1", text="Spain")
treeview.insert("item1", "1", "item2", text="Madrid")
treeview.insert("", "2", "item3", text="France")
treeview.insert("item3", "4", "item4", text="Paris")


def callback(event) : 
    item= treeview.identify("item", event.x, event.y)
    print(item)

treeview.bind("<Double-1>", callback)

# LISTBOX
#farkli farkli itemlari depolamak icin kullandigimiz yapilardir

listBox = tk.Listbox(tab2, selectmode=tk.MULTIPLE)
listBox.insert(0,"Spain")
listBox.insert(1,"France")
listBox.insert(2,"China")

listBox.place(x=5, y = 5)
def getItem():
    index_list = listBox.curselection()
    print(index_list)
    for each in index_list:
        print(listBox.get(each))

button = tk.Button(tab2, text="button", command = getItem)
button.place(x = 220, y = 5)


# Text EDITOR

texteditor = tk.Text(tab3, width = 25, height = 25, wrap = tk.WORD)
texteditor.grid(row = 0, column = 0, padx=10,pady=10)


def textFunction():
    print(texteditor.get(1.0,tk.END))



button = tk.Button(tab3, text="save", command = textFunction)
button.grid(row = 0, column = 1, padx=10,pady=10)


#scroll

scroll = tk.Scrollbar(tab3,orient=tk.VERTICAL, command = texteditor.yview)
scroll.grid(row=0,column =2, sticky=tk.N + tk.S)
texteditor.config(yscrollcomman = scroll.set)



window.mainloop()
# Out:
# ceyhun
# ...

# %%
# FILE DIALOG
import tkinter as tk
from tkinter import filedialog
from PIL import ImageTk, Image

window = tk.Tk() # high Level Window
window.geometry("500x800")

def openFile():
    #filedialog.askopenfilename(initialdir = "Catalina-Veriler\Kullanicilar\ceyhun\MAsaustu\CALISMALARIM", title = "select a file ...") bu sekilde yazinca dosya gorulur ama acilmaz, acilabilmesi icin file_name diye atamaliyiz cunku burda bir string doner
    file_name = filedialog.askopenfilename(initialdir = "Catalina-Veriler\Kullanicilar\ceyhun\MAsaustu\CALISMALARIM", title = "select a file ...")
    img = Image.open(file_name)
    img = ImageTk.PhotoImage(img)

    label = tk.Label(window, image = img)
    label.image = img
    label.pack(padx=15, pady = 15)

button = tk.Button(window, text = "open file", command = openFile)
button.pack()

window.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import ImageTk, Image
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import numpy as np


window = tk.Tk() # high Level Window
window.geometry("500x800")

def openFile():
    file_name = filedialog.askopenfilename(initialdir = "Catalina-Veriler\Kullanicilar\ceyhun\MAsaustu\CALISMALARIM", title = "select a file ...")
    img = Image.open(file_name)
    img = ImageTk.PhotoImage(img)

    label = tk.Label(window, image = img)
    label.image = img
    label.pack(padx=15, pady = 15)

button = tk.Button(window, text = "open file", command = openFile)
button.pack()


# Plot

fig = Figure(figsize = (5,4), dpi = 50)

data = np.arange(0,3,0.1)

fig.add_subplot(111).plot(data,data*2+10)

canvas = FigureCanvasTkAgg(fig, master = window)
canvas.draw()
canvas.get_tk_widget().pack()






window.mainloop()

# %%
# MOUSE EVENT


import tkinter as tk
from tkinter import filedialog
from PIL import ImageTk, Image
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import numpy as np


window = tk.Tk() # high Level Window
window.geometry("500x800")

def openFile():
    file_name = filedialog.askopenfilename(initialdir = "Catalina-Veriler\Kullanicilar\ceyhun\MAsaustu\CALISMALARIM", title = "select a file ...")
    img = Image.open(file_name)
    img = ImageTk.PhotoImage(img)

    label = tk.Label(window, image = img)
    label.image = img
    label.pack(padx=15, pady = 15)

button = tk.Button(window, text = "open file", command = openFile)
button.pack()


# Plot

fig = Figure(figsize = (5,4), dpi = 50)

data = np.arange(0,3,0.1)

fig.add_subplot(111).plot(data,data*2+10)

canvas = FigureCanvasTkAgg(fig, master = window)
canvas.draw()
canvas.get_tk_widget().pack()


# mouse event

def leftClick(event):
    tk.Label(window, text = "left").pack()

def middleClick(event):
    tk.Label(window, text = "middle").pack()


def rightClick(event):
    tk.Label(window, text = "right").pack()


window.bind("<Button-1>",leftClick)
window.bind("<Button-2>",middleClick)
window.bind("<Button-3>",RightClick)

window.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox

from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

window = tk.Tk()
window.geometry("1080x640")
window.wm_title("Trading")

pw = ttk.Panedwindow(window, orient= tk.HORIZONTAL)
pw.pack(fill=tk.BOTH, expand = True)

w2 = ttk.Panedwindow(pw, orient= tk.VERTICAL)

frame1 = ttk.Frame(pw, width = 360, height = 640, relief = tk.SUNKEN)
frame2 = ttk.Frame(pw, width = 720, height = 400, relief = tk.SUNKEN)
frame3 = ttk.Frame(pw, width = 720, height = 240, relief = tk.SUNKEN)

w2.add(frame2)
w2.add(frame3)


pw.add(w2)
pw.add(frame1)

#frame1 : treeview, open trade button

item = ""




def callback(event):
    global item
    item = treeview.identify("item",event.x, event.y)
    print("Clicked", item)


treeview = ttk.Treeview(frame1)
treeview.grid(row = 0, column = 1, padx=25, pady=25)
treeview.insert("","0","Major", text = "Major")
treeview.insert("Major", "1", "EUR/USD", text = "EUR/USD")
treeview.insert("","2","Minor", text = "Minor")
treeview.insert("Minor", "3", "EUR/GBP", text = "EUR/GBP")

treeview.bind("<Double-1>", callback)

#button

def readNews(item):
    if item == "EUR/USD":
        news = pd.read_csv("news_EURUSD.txt")
        
    elif item == "EUR/GBP":
        news = pd.read_csv("news_EURGBR.txt")
    textBox.insert(tk.INSERT,news)


def openTrade():
    global data, future, line, canvas, data_close_array, future_array,ax1,line2,canvas2,ax2,line3,ax3,canvas3,line4,canvas4,ax4
    print("opentrade")
    if item != "":
        print("chosen item : ", item)
        
        if item =="EUR/USD":
        #button settings
            open_button.config(state = "disabled")
            start_button.config(state = "normal")
            
            #data
            data = pd.read_csv("eurusd.csv")
            
            future = data[-1000:]
            data = data[:len(data)-1000]
            data_close_array = data.close1.values
            future_array = list(future.close1.values)
            
            #line
            
            fig1 = plt.Figure(figsize = (5,4), dpi = 100)
            ax1 = fig1.add_subplot(111) # 1. satir, 1. sutun a 1 tane resim,plot koycam
            line, = ax1.plot(range(len(data)), data.close1, color = "blue") # line a 2 deger doner ama 1 tanesini istiyorum dgeri cok onemli degil
            
            canvas = FigureCanvasTkAgg(fig1, master = tab1)
            canvas.draw()
            canvas.get_tk_widget().pack(side = tk.TOP, fill = tk.BOTH, expand = True)
            
            # scatter
            
            fig2 = plt.Figure(figsize = (5,4), dpi = 100)
            ax2 = fig2.add_subplot(111)
            line2 = ax2.scatter(range(len(data)), data.close1, s = 1, alpha = 0.5, color = "red")
            canvas2 = FigureCanvasTkAgg(fig2, master = tab2)
            canvas2.draw()
            canvas2.get_tk_widget().pack(side = tk.TOP, fill = tk.BOTH, expand = 1)
            
            readNews(item)
        
        elif item =="EUR/GBP":
            #button settings
            open_button.config(state = "disabled")
            start_button.config(state = "normal")
            
            #data
            data = pd.read_csv("eurgbr.csv")
            
            future = data[-1000:]
            data = data[:len(data)-1000]
            data_close_array = data.close1.values
            future_array = list(future.close1.values)
            
            #line
            
            fig3 = plt.Figure(figsize = (5,4), dpi = 100)
            ax3 = fig3.add_subplot(111) # 1. satir, 1. sutun a 1 tane resim,plot koycam
            line3, = ax3.plot(range(len(data)), data.close1, color = "blue") # line a 2 deger doner ama 1 tanesini istiyorum dgeri cok onemli degil
            
            canvas3 = FigureCanvasTkAgg(fig3, master = tab1)
            canvas3.draw()
            canvas3.get_tk_widget().pack(side = tk.TOP, fill = tk.BOTH, expand = True)
            
            # scatter
            
            fig4 = plt.Figure(figsize = (5,4), dpi = 100)
            ax4 = fig4.add_subplot(111)
            line4 = ax4.scatter(range(len(data)), data.close1, s = 1, alpha = 0.5, color = "red")
            canvas4 = FigureCanvasTkAgg(fig4, master = tab2)
            canvas4.draw()
            canvas4.get_tk_widget().pack(side = tk.TOP, fill = tk.BOTH, expand = 1)
            
            readNews(item)
            
            
        else:
            messagebox.showinfo(title = "Warning", message = "Double Click to Choose Currency Pair")    
    else : 
        messagebox.showinfo(title = "Warning", message = "Double Click to Choose Currency Pair")            
            
    
open_button = tk.Button(frame1, text = "Open Trading", command = openTrade)
open_button.grid(row = 2, column = 1, padx=5, pady=5)
    
 # frame3: text editor,scrollbar
 
textBox = tk.Text(frame3, width = 70, height=10, wrap = "word")
textBox.grid(row = 0, column = 0, padx=25,pady=10)
scroll = tk.Scrollbar(frame3, orient=tk.VERTICAL, command = textBox.yview)
scroll.grid(row = 0, column = 1, sticky = tk.N + tk.S, pady = 2)
textBox.config(yscrollcommand=scroll.set)
    

#frame2 : tabview, radiobuttons, button, labelframe ve plot

tabs = ttk.Notebook(frame2, width = 500, height=300)
tabs.place(x = 25, y = 25)
tab1 = ttk.Frame(tabs, width = 50, height= 50)
tab2 = ttk.Frame(tabs)

tabs.add(tab1, text = "Line")
tabs.add(tab2, text = "Scatter", compound = tk.LEFT) # compound sola yaslar

# radiobutton

method = tk.StringVar() # stringVar, radiobuttonda bulunan verileri okumak icin
tk.Radiobutton(frame2, text = "m1 : ", value = "m1", variable = method).place(x = 580, y = 100)
tk.Radiobutton(frame2, text = "m2 : ", value = "m2", variable = method).place(x = 580, y = 125)

# LAbelFrame

label_frame = tk.LabelFrame(frame2, text = "Result", width = 100, height = 150)
label_frame.place(x = 580, y = 25)
tk.Label(label_frame, text = "Buy: ", bd = 3).grid(row = 0, column = 0)
tk.Label(label_frame, text = "Sell: ", bd = 3).grid(row = 1, column = 0)
# buy-sell labels

buy_value = tk.Label(label_frame, text = "1",bd = 3)
buy_value.grid(row = 0, column = 1)
sell_value = tk.Label(label_frame, text = "0",bd = 3)
sell_value.grid(row = 1, column = 1)


def moving_average(a,n = 50):
    ret = np.cumsum(a, dtype = float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n-1:]/n

def update():
    global data_close_array, ax1,ax2,ax3,ax4
    spread = 0.0002
    buy_value.config(text = str((data_close_array[-1]-spread).round(5)))
    sell_value.config(text = str((data_close_array[-1]+spread).round(5)))
    
    window.after(500,update)
    data_close_array = np.append(data_close_array, future_array.pop(0))
    
    if method.get()=="m1":
        if item == "EUR/USD" :
            #line
            ax1.set_xlim(0,len(data_close_array) + 10)
            line.set_ydata(data_close_array)
            line.set_xdata(range(len(data_close_array)))
            
            #scatter
            
            ax2.set_xlim(0,len(data_close_array) + 10)
            ax2.scatter(range(len(data_close_array)), data_close_array, s=1,alpha=0.5, color = "blue")
            
            #moving average
            n = 50 
            mid_rolling = moving_average(data_close_array,n)
            ax1.plot(range(n-1,len(data_close_array)), mid_rolling,linestyle = "--", color = "red")
            ax2.plot(range(n-1,len(data_close_array)), mid_rolling,linestyle = "--", color = "red")
            canvas.draw()
            canvas2.draw()
            
            
        elif item == "EUR/GBP" :
            #line
            ax3.set_xlim(0,len(data_close_array) + 10)
            line3.set_ydata(data_close_array)
            line3.set_xdata(range(len(data_close_array)))
            
            #scatter
            
            ax4.set_xlim(0,len(data_close_array) + 10)
            ax4.scatter(range(len(data_close_array)), data_close_array, s=1,alpha=0.5, color = "blue")
            
            #moving average
            n = 50 
            mid_rolling = moving_average(data_close_array,n)
            ax3.plot(range(n-1,len(data_close_array)), mid_rolling,linestyle = "--", color = "red")
            ax4.plot(range(n-1,len(data_close_array)), mid_rolling,linestyle = "--", color = "red")
            canvas3.draw()
            canvas4.draw()
            
    elif method.get()=="m2":
        if item == "EUR/USD" :
            #line
            ax1.set_xlim(0,len(data_close_array) + 10)
            line.set_ydata(data_close_array)
            line.set_xdata(range(len(data_close_array)))
            
            #scatter
            
            ax2.set_xlim(0,len(data_close_array) + 10)
            ax2.scatter(range(len(data_close_array)), data_close_array, s=1,alpha=0.5, color = "blue")
            
            #moving average
            n = 200 
            long_rolling = moving_average(data_close_array,n)
            ax1.plot(range(n-1,len(data_close_array)), long_rolling,linestyle = "--", color = "green")
            ax2.plot(range(n-1,len(data_close_array)), long_rolling,linestyle = "--", color = "green")
            canvas.draw()
            canvas2.draw()
            
            
        elif item == "EUR/GBP" :
            #line
            ax3.set_xlim(0,len(data_close_array) + 10)
            line3.set_ydata(data_close_array)
            line3.set_xdata(range(len(data_close_array)))
            
            #scatter
            
            ax4.set_xlim(0,len(data_close_array) + 10)
            ax4.scatter(range(len(data_close_array)), data_close_array, s=1,alpha=0.5, color = "blue")
            
            #moving average
            n = 200 
            long_rolling = moving_average(data_close_array,n)
            ax3.plot(range(n-1,len(data_close_array)), long_rolling,linestyle = "--", color = "green")
            ax4.plot(range(n-1,len(data_close_array)), long_rolling,linestyle = "--", color = "green")
            canvas3.draw()
            canvas4.draw()
        
        else : 
            if item == "EUR/USD" :
            #line
                ax1.set_xlim(0,len(data_close_array) + 10)
                line.set_ydata(data_close_array)
                line.set_xdata(range(len(data_close_array)))
            
            #scatter
            
                ax2.set_xlim(0,len(data_close_array) + 10)
                ax2.scatter(range(len(data_close_array)), data_close_array, s=1,alpha=0.5, color = "blue")
            
            #moving average
            
                canvas.draw()
                canvas2.draw()
            elif item == "EUR/GBP" :
                #line
                ax3.set_xlim(0,len(data_close_array) + 10)
                line3.set_ydata(data_close_array)
                line3.set_xdata(range(len(data_close_array)))

                #scatter

                ax4.set_xlim(0,len(data_close_array) + 10)
                ax4.scatter(range(len(data_close_array)), data_close_array, s=1,alpha=0.5, color = "blue")

                #moving average
                
                canvas3.draw()
                canvas4.draw()


# button

def startTrading():
    window.after(0,update)
    print("startTrading")


start_button = tk.Button(frame2, text = "Start Trading", command = startTrading)
start_button.place(x = 580, y = 150)
start_button.config(state = "disabled") # daha sonra duzenlenecek


window.mainloop()
# Out:
# Clicked Major
# Clicked EUR/USD
# opentrade
# chosen item :  EUR/USD
# startTrading
